# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('C:/Users/Tushar Goel/week2.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  level_0  index        Date      Symbol Series  Prev Close  \
# 0           1        2      2  2017-05-17  HEROMOTOCO     EQ     3619.40
# 1           2        3      3  2017-05-18  HEROMOTOCO     EQ     3645.95
# 2           3        4      4  2017-05-19  HEROMOTOCO     EQ     3592.05
# 3           4        5      5  2017-05-22  HEROMOTOCO     EQ     3571.65
# 4           5        6      6  2017-05-23  HEROMOTOCO     EQ     3562.45
#
#    Open Price  High Price  Low Price  Last Price  Close Price  Average Price  \
# 0     3615.00     3683.95    3595.05     3634.10      3645.95        3651.06
# 1     3600.00     3639.00    3577.05     3586.00      3592.05        3602.46
# 2     3597.00     3656.00    3533.75     3565.00      3571.65        3593.06
# 3     3596.75     3645.00    3550.95     3580.15      3562.45        3591.90
# 4     3593.90     3619.00    3550.00     3579.00      3585.00        3584.05
#
# ...

# %% [markdown]
# # Problem 2.1

# %%
# Now Converting Date as an Index to the dataframe

df = df.set_index('Date')

# %%
df.head()
# Out:
#             Unnamed: 0  level_0  index      Symbol Series  Prev Close  \
# Date
# 2017-05-17           1        2      2  HEROMOTOCO     EQ     3619.40
# 2017-05-18           2        3      3  HEROMOTOCO     EQ     3645.95
# 2017-05-19           3        4      4  HEROMOTOCO     EQ     3592.05
# 2017-05-22           4        5      5  HEROMOTOCO     EQ     3571.65
# 2017-05-23           5        6      6  HEROMOTOCO     EQ     3562.45
#
#             Open Price  High Price  Low Price  Last Price  Close Price  \
# Date
# 2017-05-17     3615.00     3683.95    3595.05     3634.10      3645.95
# 2017-05-18     3600.00     3639.00    3577.05     3586.00      3592.05
# 2017-05-19     3597.00     3656.00    3533.75     3565.00      3571.65
# 2017-05-22     3596.75     3645.00    3550.95     3580.15      3562.45
# 2017-05-23     3593.90     3619.00    3550.00     3579.00      3585.00
#
#             Average Price  Total Traded Quantity      Turnover  No. of Trades  \
# Date
# ...

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(12, 6)})

# %%
df['Close Price'].plot(linewidth=0.5)
plt.title('Close Price Analysis')
plt.xlabel('Date')
plt.ylabel('Close Price')
# Out:
# Text(0, 0.5, 'Close Price')

# %% [markdown]
# # Problem 2.2

# %%
x = range(0,492)

# %%
y = df['Day_Perc_Change']

# %%
markerline, stemlines, baseline = plt.stem(x, y , '-')
plt.setp(baseline, color='r', linewidth=2)
plt.ylabel('Daily percentage Change')
plt.title('Stem Plot Analysis for Daily Percentage Change')
plt.show()
# Out:
# C:\Users\Tushar Goel\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   """Entry point for launching an IPython kernel.

# %% [markdown]
# # Problem 2.3

# %%
# Plotting Daily Volume 
plt.title('Total Volume change ')
df['Total Traded Quantity'].plot(linewidth=0.5)

# %% [markdown]
# ## comparing the two graph 1. Daily Volume and 2. Daily Perc Change stem plot

# %%
# Plotting Daily Volume...
plt.subplot(2,1,1)
plt.title('Total Volume change ')
df['Total Traded Quantity'].plot(linewidth=0.5)
plt.subplot(2,1,2)
# Stem Plot for Daily Percentage Change
markerline, stemlines, baseline = plt.stem(x, y , '-')
plt.setp(baseline, color='r', linewidth=2)
plt.show()
# Out:
# C:\Users\Tushar Goel\Anaconda3\lib\site-packages\ipykernel_launcher.py:7: UserWarning: In Matplotlib 3.3 individual lines on a stem plot will be added as a LineCollection instead of individual lines. This significantly improves the performance of a stem plot. To remove this warning and switch to the new behaviour, set the "use_line_collection" keyword argument to True.
#   import sys

# %% [markdown]
# ### It can be observed from the comparison of the two graph that whenever there is High change in "Total Traded Quantity" then there is less "Daily_Perc_Change".

# %% [markdown]
# ## Let us see through the correlation Between them

# %%
df['Total Traded Quantity'].corr(df['Day_Perc_Change'])
# Out:
# 0.11198355072421884

# %% [markdown]
# ### As it is small ,  then Our Analysis is Right . As Total traded Quantity doesn't depend highly on Daily Perc Change

# %% [markdown]
# # Problem 2.4

# %%
df['Trends'].value_counts()
# Out:
# Slight or No Change    492
# Name: Trends, dtype: int64

# %%
#data To plot
labels ={'Slight or No change','Slight positive','Slight negative','Positive','Negative','Among top gainers','Among top losers','Bull run','Bear drop'}
sizes = [492,0,0,0,0,0,0,0,0]
plt.pie(sizes , labels=labels,autopct='%1.1f%%')
plt.axis('equal')
plt.show()

# %%
ts = df.groupby('Trends')
ts.first()
# Out:
#                      Unnamed: 0  level_0  index        Date      Symbol  \
# Trends
# Slight or No Change           1        2      2  2017-05-17  HEROMOTOCO
#
#                     Series  Prev Close  Open Price  High Price  Low Price  \
# Trends
# Slight or No Change     EQ      3619.4      3615.0     3683.95    3595.05
#
#                      Last Price  Close Price  Average Price  \
# Trends
# Slight or No Change      3634.1      3645.95        3651.06
#
#                      Total Traded Quantity      Turnover  No. of Trades  \
# Trends
# Slight or No Change                 338342  1.235308e+09          27003
#
#                      Deliverable Qty  % Dly Qt to Traded Qty  Day_Perc_Change
# Trends
# Slight or No Change           160855                   47.54         0.007335

# %%
from statistics import *

# %%
mean_list = list()
median_list = list()

for name,group in ts:
    
    mean_list.append(mean(group['Total Traded Quantity']))
    median_list.append(median(group['Total Traded Quantity']))

# %%
a= 0
for i in range(8):
    mean_list.append(a)
    median_list.append(a)

# %%
labels =('Slight or No change','Slight positive','Slight negative','Positive','Negative','Among top gainers','Among top losers','Bull run','Bear drop')

# %%
plt.subplot(2,1,1)
y_pos = np.arange(len(labels))
plt.bar(y_pos, mean_list, align='center', alpha=0.5)
plt.xticks(y_pos,labels)
plt.title('Mean')
plt.subplot(2,1,2)
plt.bar(y_pos,median_list,align='center',alpha=0.5)
plt.xticks(y_pos,labels)
plt.title('Median')
# Out:
# Text(0.5, 1.0, 'Median')

# %% [markdown]
# # Problem 2.5

# %%
counts, bins = np.histogram(df['Day_Perc_Change'])
plt.hist(bins[:-1], bins, weights=counts)
# Out:
# (array([  3.,   6.,  16., 106., 226.,  99.,  27.,   3.,   4.,   2.]),
#  array([-0.06263048, -0.04897249, -0.03531451, -0.02165652, -0.00799853,
#          0.00565945,  0.01931744,  0.03297543,  0.04663341,  0.0602914 ,
#          0.07394939]),
#  <a list of 10 Patch objects>)

# %% [markdown]
# # Problem 2.6

# %%
# Loading Different Stocks
stock_1 = pd.read_csv("C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/ASHOKA.csv")
stock_2 = pd.read_csv("C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/BAJAJELEC.csv")
stock_3 = pd.read_csv("C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/FORTIS.csv")
stock_4 = pd.read_csv("C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/IDFC.csv")
stock_5 = pd.read_csv("C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/CENTURYPLY.csv")

# %%
# Loading Stock 1
stock_1.head()
# Out:
#    Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0  ASHOKA     EQ  15-May-2017      210.35       211.0       217.5     206.15
# 1  ASHOKA     EQ  16-May-2017      216.05       212.3       216.0     211.00
# 2  ASHOKA     EQ  17-May-2017      214.90       214.3       218.7     212.10
# 3  ASHOKA     EQ  18-May-2017      217.00       216.0       216.6     208.00
# 4  ASHOKA     EQ  19-May-2017      209.65       212.1       213.9     205.05
#
#    Last Price  Close Price  Average Price  Total Traded Quantity     Turnover  \
# 0      216.30       216.05         212.63                 159997  34020520.45
# 1      214.00       214.90         213.24                 213214  45466299.10
# 2      216.55       217.00         215.97                 383131  82743402.10
# 3      210.00       209.65         211.74                  78709  16665707.55
# 4      206.05       206.25         209.95                 398725  83713500.05
#
# ...

# %%
stock_2.head()
# Out:
#       Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  BAJAJELEC     EQ  15-May-2017      350.75      351.20      352.30
# 1  BAJAJELEC     EQ  16-May-2017      341.15      342.90      350.50
# 2  BAJAJELEC     EQ  17-May-2017      347.00      347.10      352.00
# 3  BAJAJELEC     EQ  18-May-2017      349.85      346.95      346.95
# 4  BAJAJELEC     EQ  19-May-2017      334.10      339.05      344.00
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     339.10       342.0       341.15         344.83                 150265
# 1     341.65       346.6       347.00         346.14                 118849
# 2     345.85       349.5       349.85         349.90                 108592
# 3     331.50       336.0       334.10         339.31                 158652
# 4     332.00       335.5       336.20         338.64                 129244
#
#       Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
stock_3.head()
# Out:
#    Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0  FORTIS     EQ  15-May-2017      208.40      208.40      209.65     204.05
# 1  FORTIS     EQ  16-May-2017      205.25      206.25      209.45     205.45
# 2  FORTIS     EQ  17-May-2017      207.90      208.00      210.80     204.90
# 3  FORTIS     EQ  18-May-2017      205.90      204.00      205.25     195.00
# 4  FORTIS     EQ  19-May-2017      196.85      197.80      204.90     196.45
#
#        Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0          206.75       205.25         205.66                9078354
# 1          207.70       207.90         207.86                2146212
# 2          205.30       205.90         208.01                3032479
# 3          195.80       196.85         200.05                2852401
# 4          204.20       203.55         200.95                4144993
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
stock_4.head()
# Out:
#   Symbol Series         Date  Prev Close  Open Price  High Price  Low Price  \
# 0   IDFC     EQ  15-May-2017       63.35       63.95       64.35      63.25
# 1   IDFC     EQ  16-May-2017       63.70       64.00       64.60      62.90
# 2   IDFC     EQ  17-May-2017       64.25       64.65       64.65      63.25
# 3   IDFC     EQ  18-May-2017       63.35       62.40       62.60      61.20
# 4   IDFC     EQ  19-May-2017       61.50       61.85       62.30      60.30
#
#    Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0       63.65        63.70          63.74                2754130
# 1       64.55        64.25          63.80                4014549
# 2       63.25        63.35          63.58                4184709
# 3       61.35        61.50          61.85                6040654
# 4       61.00        61.15          61.20                3697284
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
stock_5.head()
# Out:
#        Symbol Series         Date  Prev Close  Open Price  High Price  \
# 0  CENTURYPLY     EQ  15-May-2017      255.65      256.75      267.90
# 1  CENTURYPLY     EQ  16-May-2017      266.65      270.00      271.00
# 2  CENTURYPLY     EQ  17-May-2017      266.10      267.95      267.95
# 3  CENTURYPLY     EQ  18-May-2017      264.85      264.00      264.00
# 4  CENTURYPLY     EQ  19-May-2017      260.35      261.35      265.00
#
#    Low Price  Last Price  Close Price  Average Price  Total Traded Quantity  \
# 0     254.05       267.5       266.65         263.57                 206437
# 1     263.20       265.4       266.10         266.37                 221371
# 2     262.00       264.0       264.85         264.49                 429282
# 3     253.60       261.0       260.35         259.43                  73215
# 4     252.50       254.6       254.05         256.99                 105993
#
#        Turnover  No. of Trades  Deliverable Qty  % Dly Qt to Traded Qty
# ...

# %%
#dropping row of stocks having Series value not equal to EQ
stock_1 = stock_1[stock_1.Series == 'EQ']
stock_2 = stock_2[stock_2.Series == 'EQ']
stock_3 = stock_3[stock_3.Series == 'EQ']
stock_4 = stock_4[stock_4.Series == 'EQ']
stock_5 = stock_5[stock_5.Series == 'EQ']

# %%
# Creating  a Dataframe having close price of different stocks
df_1 = pd.DataFrame()

# %%
df_1['Ashoka'] = stock_1['Close Price']
df_1['BajajElec'] = stock_2['Close Price']
df_1['Fortis'] = stock_3['Close Price']
df_1['IDFC'] = stock_4['Close Price']
df_1['CenturyPly'] = stock_5['Close Price']

# %%
df_1.head()
# Out:
#    Ashoka  BajajElec  Fortis   IDFC  CenturyPly
# 0  216.05     341.15  205.25  63.70      266.65
# 1  214.90     347.00  207.90  64.25      266.10
# 2  217.00     349.85  205.90  63.35      264.85
# 3  209.65     334.10  196.85  61.50      260.35
# 4  206.25     336.20  203.55  61.15      254.05

# %%
# Creating a New Data frame having percentage change of df_1
df_2 = pd.DataFrame()
df_2['Ashoka'] = stock_1['Close Price'].pct_change()
df_2['BajajElec'] = stock_2['Close Price'].pct_change()
df_2['Fortis'] = stock_3['Close Price'].pct_change()
df_2['IDFC'] = stock_4['Close Price'].pct_change()
df_2['CenturyPly'] = stock_5['Close Price'].pct_change()

# %%
df_2.head()
# Out:
#      Ashoka  BajajElec    Fortis      IDFC  CenturyPly
# 0       NaN        NaN       NaN       NaN         NaN
# 1 -0.005323   0.017148  0.012911  0.008634   -0.002063
# 2  0.009772   0.008213 -0.009620 -0.014008   -0.004697
# 3 -0.033871  -0.045019 -0.043953 -0.029203   -0.016991
# 4 -0.016218   0.006286  0.034036 -0.005691   -0.024198

# %%
# Removing the NaN value
df_2 = df_2.drop(df_2.head(1).index)

# %%
df_2
# Out:
#        Ashoka  BajajElec    Fortis      IDFC  CenturyPly
# 1   -0.005323   0.017148  0.012911  0.008634   -0.002063
# 2    0.009772   0.008213 -0.009620 -0.014008   -0.004697
# 3   -0.033871  -0.045019 -0.043953 -0.029203   -0.016991
# 4   -0.016218   0.006286  0.034036 -0.005691   -0.024198
# 5   -0.022545  -0.068263 -0.042987 -0.015536    0.005708
# 6   -0.019593   0.007342  0.008984 -0.032392   -0.029550
# 7   -0.008348   0.039296 -0.011193 -0.023176   -0.027828
# 8    0.018112   0.055649  0.042192  0.012302    0.048123
# 9    0.001754   0.038273  0.000987  0.028646    0.027706
# 10   0.000750  -0.029907 -0.032799 -0.015190   -0.000770
# 11  -0.025744  -0.016777  0.010454  0.013710   -0.005589
# 12  -0.023345  -0.002333 -0.015140 -0.001691    0.024806
# 13  -0.014972  -0.001754  0.016398  0.001693    0.034039
# 14   0.014667   0.031337 -0.027225  0.004227    0.002743
# 15   0.009198   0.015476  0.010106 -0.006734    0.026810
# ...

# %%
import seaborn as sns
sns.pairplot(df_2)
# Out:
# C:\Users\Tushar Goel\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\Tushar Goel\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %% [markdown]
# # Problem 2.7

# %% [markdown]
# ## Calculating volatility for ASHOKA

# %%
df_2.Ashoka.rolling(7).std().plot(color='red')

# %% [markdown]
# # Problem 2.8

# %% [markdown]
# # Plotting the Volatility for NIFTY50

# %%
df_nifty = pd.read_csv("C:/Users/Tushar Goel/Desktop/Intern related dataset/Nifty50.csv")
df_nifty.head()
# Out:
#           Date     Open     High      Low    Close  Shares Traded  \
# 0  15-May-2017  9433.55  9449.25  9423.10  9445.40      145163953
# 1  16-May-2017  9461.00  9517.20  9456.35  9512.25      171709433
# 2  17-May-2017  9517.60  9532.60  9486.10  9525.75      211856040
# 3  18-May-2017  9453.20  9489.10  9418.10  9429.45      199340647
# 4  19-May-2017  9469.90  9505.75  9390.75  9427.90      259861396
#
#    Turnover (Rs. Cr)
# 0            7790.97
# 1            9209.89
# 2           10726.23
# 3           10782.46
# 4           11544.77

# %% [markdown]
# ## On comparing on subplots

# %%
plt.subplot(2,1,1)
df_nifty.Close.rolling(7).std().plot(color='blue')
plt.subplot(2,1,2)
df_2.Ashoka.rolling(7).std().plot(color='red')

# %% [markdown]
# ## Merging the two

# %%
df_nifty.Close.rolling(7).std().plot(color='blue')
df_2.Ashoka.rolling(7).std().plot(color='red')
plt.legend()

# %% [markdown]
# ### The red line is ASHOKA and The Blue line is Nifty50

# %% [markdown]
# # Problem 2.9

# %%
df.reset_index(inplace=True)

# %%
df.set_index('Date',inplace=True)

# %%
# lets create a function
# which can provide the datapoint
def trade_call(data,Period):
    j = next(i for i, x in enumerate(data) if x is not None)
    our_range = range(len(data))[j + Period - 1:]
    empty_list = [None] * (j + Period - 1)
    sub_result = [np.mean(data[i - Period + 1: i + 1]) for i in our_range]

    return np.array(empty_list + sub_result)

# %%
trade_call(df['Average Price'],21)
# Out:
# array([None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None,
#        3710.7171428571432, 3717.0990476190477, 3725.578571428571,
#        3736.468571428571, 3746.702857142857, 3755.7104761904766,
#        3764.658095238095, 3768.848095238095, 3770.5333333333333,
#        3773.267619047618, 3773.096666666666, 3770.5076190476184,
#        3768.7847619047625, 3763.937142857143, 3757.349047619048,
#        3753.995714285714, 3746.667619047619, 3743.0590476190478,
#        3741.7066666666665, 3739.5876190476197, 3739.207619047619,
#        3738.214761904762, 3737.1042857142843, 3737.1642857142847,
#        3734.8271428571425, 3731.362857142857, 3728.1452380952383,
#        3725.4985714285713, 3727.7566666666658, 3729.959047619047,
#        3731.4661904761897, 3728.950476190476, 3726.6833333333334,
#        3724.6880952380952, 3728.451904761904, 3733.84619047619,
# ...

# %%
trade_call(df['Average Price'],34)
# Out:
# array([None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        None, None, None, None, None, None, None, None, None, None, None,
#        3722.2847058823536, 3723.98705882353, 3727.8420588235294,
#        3730.7029411764706, 3734.609117647059, 3739.5211764705887,
#        3744.3814705882355, 3749.3708823529414, 3753.2497058823533,
#        3756.801176470588, 3758.8979411764703, 3759.8041176470583,
#        3758.554411764706, 3754.955882352941, 3750.698529411765,
#        3748.3382352941167, 3744.6164705882347, 3742.5455882352935,
#        3738.8579411764695, 3734.7376470588233, 3732.7544117647053,
#        3733.238529411764, 3734.33088235294, 3738.2661764705877,
#        3742.6561764705875, 3746.5741176470583, 3749.9344117647056,
#        3754.3761764705882, 3758.9464705882347, 3766.6661764705877,
#        3775.865294117646, 3784.489705882352, 3793.151764705882,
# ...

# %%
tra = pd.DataFrame()

# %%
tra['Date'] = df['Date']
tra['smallSMA'] = trade_call(df['Average Price'],21)
tra['largeSMA'] = trade_call(df['Average Price'],34)

# %%
tra['smallSMA'].plot(color='Red')
tra['largeSMA'].plot(color='Blue')
plt.legend()

# %%
# Create signals
tra['signal']=0.0
tra['signal'][21:] = np.where(tra['smallSMA'][21:] 
                                            > tra['largeSMA'][21:], 1.0, 0.0)   

# Generate trading orders
tra['positions'] = tra['signal'].diff()

# Print `signals`
print(tra)
# Out:
#            Date smallSMA largeSMA  signal  positions
# 0    2017-05-17     None     None     0.0        NaN
# 1    2017-05-18     None     None     0.0        0.0
# 2    2017-05-19     None     None     0.0        0.0
# 3    2017-05-22     None     None     0.0        0.0
# 4    2017-05-23     None     None     0.0        0.0
# 5    2017-05-24     None     None     0.0        0.0
# 6    2017-05-25     None     None     0.0        0.0
# 7    2017-05-26     None     None     0.0        0.0
# 8    2017-05-29     None     None     0.0        0.0
# 9    2017-05-30     None     None     0.0        0.0
# 10   2017-05-31     None     None     0.0        0.0
# 11   2017-06-01     None     None     0.0        0.0
# 12   2017-06-02     None     None     0.0        0.0
# 13   2017-06-05     None     None     0.0        0.0
# 14   2017-06-06     None     None     0.0        0.0
# 15   2017-06-07     None     None     0.0        0.0
# 16   2017-06-08     None     None     0.0        0.0
# ...

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111,  ylabel='Price in $')
df['Average Price'].plot(ax=ax1, color='r', lw=2.)
tra[['smallSMA', 'largeSMA']].plot(ax=ax1, lw=2.)
#plot the buy plot
ax1.plot(tra.loc[tra.positions == 1.0].index, tra.smallSMA[tra.positions == 1.0],'^', markersize=10, color='red')
         
#Plot the sell signal
ax1.plot(tra.loc[tra.positions == -1.0].index, tra.smallSMA[tra.positions == -1.0],'v', markersize=10, color='k')
         
# Show the plot
plt.show()

# %% [markdown]
# # Problem 2.10

# %%
#Bollinger bands

rolling_std = df['Close Price'].rolling(14).std()
df['Rolling Mean'] = df['Close Price'].rolling(14).mean()
df['Upper Band'] = df['Close Price'].rolling(14).mean() + rolling_std*2
df['Lower Band'] = df['Close Price'].rolling(14).mean() - rolling_std*2

# %%
df[['Average Price','Upper Band','Lower Band']].plot()

# %% [markdown]
# ## saving df into week3.csv

# %%
df.to_csv('week4.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-0c9f950b1b2a> in <module>
# ----> 1 df.to_csv('week4.csv')
#
# NameError: name 'df' is not defined

# %% [markdown]
# #### Thankyou

# %%
df['Close Price'].rolling(14).std()
