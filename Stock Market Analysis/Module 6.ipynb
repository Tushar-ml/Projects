# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from statistics import *
import seaborn as sns
from math import sqrt

# %%
# Importing Small_Cap stocks
stock_1 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/Ashoka.csv')
stock_2 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/BajajElec.csv')
stock_3 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/Bomdyeing.csv')
stock_4 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/Centuryply.csv')
stock_5 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/Fortis.csv')
stock_6 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/GujalKali.csv')
stock_7 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/idfc.csv')
stock_8 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/ircon.csv')
stock_9 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/itdc.csv')
stock_10 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Small_Cap/jetairways.csv')

# %%
# Importing Medium_Cap stocks
stock_11 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/Adanipower.csv')
stock_12 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/ajantpharm.csv')
stock_13 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/amarajabat.csv')
stock_14 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/apollotyre.csv')
stock_15 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/bergepaint.csv')
stock_16 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/castrolind.csv')
stock_17 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/cumminsind.csv')
stock_18 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/dhfl.csv')
stock_19 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/exideind.csv')
stock_20 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Mid_Cap/gmrinfra.csv')

# %%
# Importing Large_Cap Stocks
stock_21 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/Adaniports.csv')
stock_22 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/Asianpaint.csv')
stock_23 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/axisbank.csv')
stock_24 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/bajfinance.csv')
stock_25 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/bpcl.csv')
stock_26 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/cipla.csv')
stock_27 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/drreddy.csv')
stock_28 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/eichermot.csv')
stock_29 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/gail.csv')
stock_30 = pd.read_csv('C:/Users/Tushar Goel/Desktop/Intern related dataset/Large_Cap/hdfc.csv')

# %% [markdown]
# # Creating DataFrame

# %%
df = pd.DataFrame()

# %%
df['Ashoka'] = stock_1['Close Price']
df['BajajElec'] = stock_2['Close Price']
df['BombayDyeing'] = stock_3['Close Price']
df['CenturyPly'] = stock_4['Close Price']
df['Fortis'] = stock_5['Close Price']
df['GujalKali'] = stock_6['Close Price']
df['IDFC'] = stock_7['Close Price']
df['IRCON'] = stock_8['Close Price']
df['ITDC'] = stock_9['Close Price']
df['JetAirways'] = stock_10['Close Price']
df['AdaniPower'] = stock_11['Close Price']
df['AjantPharm'] = stock_12['Close Price']
df['AmaRajaBat'] = stock_13['Close Price']
df['ApolloTyre'] = stock_14['Close Price']
df['BergePaint'] = stock_15['Close Price']
df['CastrolInd'] = stock_16['Close Price']
df['CumminSind'] = stock_17['Close Price']
df['DHFL'] = stock_18['Close Price']
df['ExideInd'] = stock_19['Close Price']
df['GmrinFra'] = stock_20['Close Price']
df['AdaniPorts'] = stock_21['Close Price']
df['AsianPaint'] = stock_22['Close Price']
df['AxisBank'] = stock_23['Close Price']
df['BajajFinance'] = stock_24['Close Price']
df['BPCL'] = stock_25['Close Price']
df['Cipla'] = stock_26['Close Price']
df['DrReddy'] = stock_27['Close Price']
df['EicherMot'] = stock_28['Close Price']
df['Gail'] = stock_29['Close Price']
df['HDFC'] = stock_30['Close Price']

# %%
df.head()
# Out:
#    Ashoka  BajajElec  BombayDyeing  CenturyPly  Fortis  GujalKali   IDFC  \
# 0  216.05     341.15         82.20      266.65  205.25     457.35  63.70
# 1  214.90     347.00         83.40      266.10  207.90     455.25  64.25
# 2  217.00     349.85         82.25      264.85  205.90     472.65  63.35
# 3  209.65     334.10         78.95      260.35  196.85     461.85  61.50
# 4  206.25     336.20         77.15      254.05  203.55     455.35  61.15
#
#    IRCON    ITDC  JetAirways  ...  AdaniPorts  AsianPaint  AxisBank  \
# 0  415.3  650.15      527.50  ...      356.20     1148.05     500.1
# 1  427.0  636.70      534.15  ...      354.50     1142.85     501.5
# 2  421.4  626.75      528.90  ...      348.55     1154.95     502.8
# 3  407.1  604.65      522.70  ...      347.90     1151.35     492.0
# 4  399.8  594.30      520.40  ...      349.45     1123.15     501.7
#
#    BajajFinance    BPCL   Cipla  DrReddy  EicherMot    Gail     HDFC
# ...

# %% [markdown]
# # Problem 6.2

# %%
#Calculate average annual percentage return and volatilities over a theoretical one year period
returns = df.pct_change().mean() * 252
returns = pd.DataFrame(returns)
returns.columns = ['Returns']
returns['Volatility'] = df.pct_change().std() * sqrt(252)

returns
# Out:
#                  Returns  Volatility
# Ashoka         -0.208509    0.442974
# BajajElec       0.316053    0.402414
# BombayDyeing    0.327621    0.602869
# CenturyPly     -0.182338    0.375269
# Fortis         -0.137297    0.421483
# GujalKali       0.112144    0.385492
# IDFC           -0.200489    0.353990
# IRCON          -0.024109    0.165945
# ITDC           -0.369385    0.527760
# JetAirways     -0.481019    0.624854
# AdaniPower      0.305273    0.610532
# AjantPharm     -0.173891    0.332171
# AmaRajaBat     -0.168654    0.267425
# ApolloTyre     -0.064303    0.310445
# BergePaint      0.108935    0.267668
# CastrolInd     -0.434557    0.446466
# CumminSind     -0.177629    0.296544
# DHFL           27.851587    8.424197
# ExideInd       -0.051484    0.262985
# GmrinFra        0.043816    0.479169
# AdaniPorts      0.071200    0.309379
# AsianPaint      0.101249    0.209406
# AxisBank        0.235246    0.277896
# BajajFinance    0.452758    0.321060
# ...

# %% [markdown]
# # Problem 6.3

# %%
#format the data as a numpy array to feed into the K-Means algorithm
data = np.asarray([np.asarray(returns['Returns']),np.asarray(returns['Volatility'])]).T
X = data
distorsions = []
for k in range(2, 20):
    k_means = KMeans(n_clusters=k,random_state=0)
    k_means.fit(X)
    distorsions.append(k_means.inertia_)

fig = plt.figure(figsize=(15, 5))
plt.plot(range(2, 20), distorsions)
# plt.grid(True)
plt.title('Elbow curve')
# Out:
# Text(0.5, 1.0, 'Elbow curve')

# %% [markdown]
# ## No of clusters =  3

# %%
from scipy.cluster.vq import kmeans,vq
from pylab import plot,show

# %%
# computing K-Means with K = 3 (3 clusters)
centroids,_ = kmeans(data,3)
# assign each sample to a cluster
idx,_ = vq(data,centroids)

# some plotting using numpy's logical indexing
plot(data[idx==0,0],data[idx==0,1],'ob',
     data[idx==1,0],data[idx==1,1],'oy',
     data[idx==2,0],data[idx==2,1],'or')
plt.legend(['Cluster 0','Cluster 1','Cluster 2'])
show()

# %% [markdown]
# # Problem 6.4

# %%
cluster_data = pd.DataFrame()
details = [(name,cluster) for name, cluster in zip(returns.index,idx)]
name = list()
cluster = list()
for detail in details:
    
        name.append(detail[0])
        cluster.append(detail[1])

# %%
cluster_data['Name'] = name
cluster_data['Cluster Number'] = cluster

# %%
cluster_data
# Out:
#             Name  Cluster Number
# 0         Ashoka               2
# 1      BajajElec               2
# 2   BombayDyeing               2
# 3     CenturyPly               2
# 4         Fortis               2
# 5      GujalKali               2
# 6           IDFC               2
# 7          IRCON               2
# 8           ITDC               2
# 9     JetAirways               2
# 10    AdaniPower               2
# 11    AjantPharm               2
# 12    AmaRajaBat               2
# 13    ApolloTyre               2
# 14    BergePaint               2
# 15    CastrolInd               2
# 16    CumminSind               2
# 17          DHFL               1
# 18      ExideInd               2
# 19      GmrinFra               2
# 20    AdaniPorts               2
# 21    AsianPaint               2
# 22      AxisBank               2
# 23  BajajFinance               2
# 24          BPCL               2
# 25         Cipla               2
# 26       DrReddy               2
# ...

# %%
df = df.T

# %%
df
# Out:
#                    0         1         2         3         4         5    \
# Ashoka          216.05    214.90    217.00    209.65    206.25    201.60
# BajajElec       341.15    347.00    349.85    334.10    336.20    313.25
# BombayDyeing     82.20     83.40     82.25     78.95     77.15     74.00
# CenturyPly      266.65    266.10    264.85    260.35    254.05    255.50
# Fortis          205.25    207.90    205.90    196.85    203.55    194.80
# GujalKali       457.35    455.25    472.65    461.85    455.35    455.25
# IDFC             63.70     64.25     63.35     61.50     61.15     60.20
# IRCON           415.30    427.00    421.40    407.10    399.80    382.05
# ITDC            650.15    636.70    626.75    604.65    594.30    574.65
# JetAirways      527.50    534.15    528.90    522.70    520.40    475.65
# AdaniPower       30.25     32.85     33.10     31.90     32.40     31.45
# AjantPharm     1633.50   1634.25   1654.35   1633.40   1670.25   1677.95
# ...

# %%
import cv2 as cv
import numpy as np

# Write down conf, nms thresholds,inp width/height
confThreshold = 0.25
nmsThreshold = 0.40
inpWidth = 416
inpHeight = 416

# Load names of classes and turn that into a list
classesFile = "E:/Yolo V3/coco.names"
classes = None

with open(classesFile, 'rt') as f:
    classes = f.read().rstrip('\n').split('\n')

# Model configuration
modelConf = 'E:/Yolo V3/yolov3.cfg'
modelWeights = 'E:/Yolo V3/yolov3.weights'


def postprocess(frame, outs):
    frameHeight = frame.shape[0]
    frameWidth = frame.shape[1]

    classIDs = []
    confidences = []
    boxes = []

    for out in outs:
        for detection in out:

            scores = detection[5:]
            classID = np.argmax(scores)
            confidence = scores[classID]

            if confidence > confThreshold:
                centerX = int(detection[0] * frameWidth)
                centerY = int(detection[1] * frameHeight)

                width = int(detection[2] * frameWidth)
                height = int(detection[3] * frameHeight)

                left = int(centerX - width / 2)
                top = int(centerY - height / 2)

                classIDs.append(classID)
                confidences.append(float(confidence))
                boxes.append([left, top, width, height])

    indices = cv.dnn.NMSBoxes(boxes, confidences, confThreshold, nmsThreshold)

    indices = cv.dnn.NMSBoxes(boxes, confidences, confThreshold, nmsThreshold)
    for i in indices:
        i = i[0]
        box = boxes[i]
        left = box[0]
        top = box[1]
        width = box[2]
        height = box[3]

        drawPred(classIDs[i], confidences[i], left, top, left + width, top + height)


def drawPred(classId, conf, left, top, right, bottom):
    # Draw a bounding box.
    cv.rectangle(frame, (left, top), (right, bottom), (255, 178, 50), 3)

    label = '%.2f' % conf

    # Get the label for the class name and its confidence
    if classes:
        assert (classId < len(classes))
        label = '%s:%s' % (classes[classId], label)

    # A fancier display of the label from learnopencv.com
    # Display the label at the top of the bounding box
    # labelSize, baseLine = cv.getTextSize(label, cv.FONT_HERSHEY_SIMPLEX, 0.5, 1)
    # top = max(top, labelSize[1])
    # cv.rectangle(frame, (left, top - round(1.5 * labelSize[1])), (left + round(1.5 * labelSize[0]), top + baseLine),
    # (255, 255, 255), cv.FILLED)
    # cv.rectangle(frame, (left,top),(right,bottom), (255,255,255), 1 )
    # cv.putText(frame, label, (left, top), cv.FONT_HERSHEY_SIMPLEX, 0.75, (0, 0, 0), 1)
    cv.putText(frame, label, (left, top), cv.FONT_HERSHEY_SIMPLEX, 2, (255, 255, 255), 3)


def getOutputsNames(net):
    # Get the names of all the layers in the network
    layersNames = net.getLayerNames()

    # Get the names of the output layers, i.e. the layers with unconnected outputs
    return [layersNames[i[0] - 1] for i in net.getUnconnectedOutLayers()]


# Set up the net

net = cv.dnn.readNetFromDarknet(modelConf, modelWeights)
net.setPreferableBackend(cv.dnn.DNN_BACKEND_OPENCV)
net.setPreferableTarget(cv.dnn.DNN_TARGET_CPU)

# Process inputs
winName = 'DL OD with OpenCV'
cv.namedWindow(winName, cv.WINDOW_NORMAL)
cv.resizeWindow(winName, 1000, 1000)

cap = cv.VideoCapture(0)

while cv.waitKey(1) < 0:
    # get frame from video
    hasFrame, frame = cap.read()

    # Create a 4D blob from a frame

    blob = cv.dnn.blobFromImage(frame, 1 / 255, (inpWidth, inpHeight), [0, 0, 0], 1, crop=False)

    # Set the input the the net
    net.setInput(blob)
    outs = net.forward(getOutputsNames(net))

    postprocess(frame, outs)

    # show the image
    cv.imshow(winName, frame)

# %%
import cv2
cap = cv2.VideoCapture(0)

while True:
    ret,frame = cap.read()
    frame  =  cv2.Canny(frame,50,150)
    cv2.imshow('frame',frame)
    
    if cv2.waitKey(1) & 0xFF ==  ord('q'):
        break
        
cap.release()
cv2.destroyAllWindows()

# %%
# ?Canny
# Out:
# Object `Canny` not found.
